# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('census-income.csv', skipinitialspace = True, na_values = '?') # na_values will change all ? into NAN values
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country annual_income
# 0          2174             0              40  United-States         <=50K
# ...

# %%
data.shape
# Out:
# (32561, 15)

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'annual_income'],
#       dtype='object')

# %%
data.columns = data.columns.str.replace('-','_')

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'annual_income'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       30725 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      30718 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  31978 non-null  object
#  14  annual_income   32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data["workclass"].value_counts()
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
data.isnull().sum()
#3Q
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# annual_income        0
# dtype: int64

# %%
data["workclass"].unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', nan, 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
#Removing null values
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# annual_income     0
# dtype: int64

# %%
#Data Manipulation
#Q Extractracting the “education” column and store it in “census_ed” .
census_ed=data[['education']]
census_ed.head()
# Out:
#    education
# 0  Bachelors
# 1  Bachelors
# 2    HS-grad
# 3       11th
# 4  Bachelors

# %%
#) Q .Extracting all the columns from “age” to “relationship” and store it in “census_seq”.
census_seq=data.iloc[:,0:8]
census_seq.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital_status         occupation   relationship
# 0       Never-married       Adm-clerical  Not-in-family
# 1  Married-civ-spouse    Exec-managerial        Husband
# 2            Divorced  Handlers-cleaners  Not-in-family
# 3  Married-civ-spouse  Handlers-cleaners        Husband
# 4  Married-civ-spouse     Prof-specialty           Wife

# %%
data.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country annual_income
# 0          2174             0              40  United-States         <=50K
# ...

# %%
census_seq = data.loc[:,'age':'relationship']
census_seq
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship
# 0           Never-married       Adm-clerical  Not-in-family
# 1      Married-civ-spouse    Exec-managerial        Husband
# ...

# %%
#Q Extract the column number “0”, “5”, “6” and store it in “census_col”.
census_col=data.iloc[:,[0,5,6]]
census_col.head()
# Out:
#    age      marital_status         occupation
# 0   39       Never-married       Adm-clerical
# 1   50  Married-civ-spouse    Exec-managerial
# 2   38            Divorced  Handlers-cleaners
# 3   53  Married-civ-spouse  Handlers-cleaners
# 4   28  Married-civ-spouse     Prof-specialty

# %%
#)Q.  Extracting all the male employees who work in state-gov and store it in “male_gov”.
male_gov=data[(data['workclass']=='State-gov') & (data['sex']=='Male')]
male_gov.head()
# Out:
#      age  workclass  fnlwgt     education  education_num      marital_status  \
# 0     39  State-gov   77516     Bachelors             13       Never-married
# 11    30  State-gov  141297     Bachelors             13  Married-civ-spouse
# 34    22  State-gov  311512  Some-college             10  Married-civ-spouse
# 48    41  State-gov  101603     Assoc-voc             11  Married-civ-spouse
# 123   29  State-gov  267989     Bachelors             13  Married-civ-spouse
#
#          occupation   relationship                race   sex  capital_gain  \
# 0      Adm-clerical  Not-in-family               White  Male          2174
# 11   Prof-specialty        Husband  Asian-Pac-Islander  Male             0
# 34    Other-service        Husband               Black  Male             0
# 48     Craft-repair        Husband               White  Male             0
# 123  Prof-specialty        Husband               White  Male             0
#
# ...

# %%
#Extract all the 39 year olds who either have a bachelor's degree or who are native of the United States and store the result in “census_us”.
census = data[(data['age']==39)]
#census
census_us=census[(census['education']=='Bachelors') | (census['native_country']==' United-States')]
census_us.head(1)
# Out:
#    age  workclass  fnlwgt  education  education_num marital_status  \
# 0   39  State-gov   77516  Bachelors             13  Never-married
#
#      occupation   relationship   race   sex  capital_gain  capital_loss  \
# 0  Adm-clerical  Not-in-family  White  Male          2174             0
#
#    hours_per_week native_country annual_income
# 0              40  United-States         <=50K

# %%
twoquest=data[(data['occupation'] == 'Tech-support') & (data['annual_income'] == '>50K')]
twoquest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 278 entries, 25 to 32457
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             278 non-null    int64
#  1   workclass       278 non-null    object
#  2   fnlwgt          278 non-null    int64
#  3   education       278 non-null    object
#  4   education_num   278 non-null    int64
#  5   marital_status  278 non-null    object
#  6   occupation      278 non-null    object
#  7   relationship    278 non-null    object
#  8   race            278 non-null    object
#  9   sex             278 non-null    object
#  10  capital_gain    278 non-null    int64
#  11  capital_loss    278 non-null    int64
#  12  hours_per_week  278 non-null    int64
#  13  native_country  278 non-null    object
#  14  annual_income   278 non-null    object
# dtypes: int64(6), object(9)
# memory usage: 34.8+ KB

# %%
df_4= data[(data['hours_per_week'] >= 40) |  (data['annual_income'] =='<=50K')]
print(df_4)
#6Q
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
census
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 0       39         State-gov   77516     Bachelors             13
# 28      39           Private  367260       HS-grad              9
# 129     39           Private  365739  Some-college             10
# 166     39       Federal-gov  235485    Assoc-acdm             12
# 320     39  Self-emp-not-inc  174308       HS-grad              9
# ...    ...               ...     ...           ...            ...
# 32260   39       Federal-gov  232036  Some-college             10
# 32378   39           Private  214896       HS-grad              9
# 32428   39       Federal-gov  110622     Bachelors             13
# 32468   39  Self-emp-not-inc  193689       HS-grad              9
# 32545   39         Local-gov  111499    Assoc-acdm             12
#
#            marital_status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# ...

# %%
# Q sample() helps us to get random rows
census_200= data.sample(200)
census_200
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 8064    31       Federal-gov  334346     Bachelors             13
# 26651   19           Private  204389       HS-grad              9
# 24573   35           Private  422933     Bachelors             13
# 14490   48           Private  181758  Some-college             10
# 30055   40      Self-emp-inc  132222       HS-grad              9
# ...    ...               ...     ...           ...            ...
# 30664   54           Private   77336       HS-grad              9
# 851     26           Private   90980     Assoc-voc             11
# 11231   23           Private  170482  Some-college             10
# 24953   30  Self-emp-not-inc  196342  Some-college             10
# 15758   24           Private   42401     Bachelors             13
#
#            marital_status       occupation   relationship   race     sex  \
# 8064   Married-civ-spouse  Exec-managerial        Husband  White    Male
# ...

# %%
#Extracting males and females seperately whose income is more than 50k
male_50k=data[(data['sex']=='Male') & (data['annual_income']=='>50K')]
female_50K=data[(data['sex']=='Female') & (data['annual_income']=='>50K')]

# %%
female_50K
# Out:
#        age         workclass  fnlwgt    education  education_num  \
# 8       31           Private   45781      Masters             14
# 19      43  Self-emp-not-inc  292175      Masters             14
# 52      47           Private   51835  Prof-school             15
# 67      53           Private  169846      HS-grad              9
# 84      44           Private  343591      HS-grad              9
# ...    ...               ...     ...          ...            ...
# 32513   46           Private   42972      Masters             14
# 32536   34           Private  160216    Bachelors             13
# 32538   38           Private  139180    Bachelors             13
# 32545   39         Local-gov  111499   Assoc-acdm             12
# 32560   52      Self-emp-inc  287927      HS-grad              9
#
#            marital_status       occupation   relationship   race     sex  \
# 8           Never-married   Prof-specialty  Not-in-family  White  Female
# ...

# %%
male_50k
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 20      40           Private  193524     Doctorate             16
# ...    ...               ...     ...           ...            ...
# 32519   46           Private  364548  Some-college             10
# 32532   34           Private  204461     Doctorate             16
# 32533   54           Private  337992     Bachelors             13
# 32554   53           Private  321865       Masters             14
# 32557   40           Private  154374       HS-grad              9
#
#            marital_status         occupation relationship                race  \
# 7      Married-civ-spouse    Exec-managerial      Husband               White
# ...

# %%
#Calculatig the percentage of high school graduates earning more than 50,000 annually

total = len(data['education'])
hs_m50k=len(data[(data['education']=='HS-grad') &(data['annual_income']=='>50K')])

percentage_hs_m50k=(hs_m50k/total)*100

percentage_hs_m50k
# Out:
# 5.361050328227571

# %%
data.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country annual_income
# 0          2174             0              40  United-States         <=50K
# ...

# %% [markdown]
# # Linear Regression Model

# %%
# Target column : Hours per week
# Independent column : Education_num

# %%
# Model building part

# seperate independent and dependent columns
# train test split
# build our model --- checking for classification or regression models ----> fit_transform
# make predictions
# evaluating our model
# if a classification model :  accuracy score, confusion matrix, classification report
# if a regression model : r2 score, adjusted r2 score, mse, rmse, mae

# %%
data1 = pd.read_csv(r"C:\Users\hp\Downloads\data.csv", skipinitialspace = True, na_values = '?') # na_values will change all ? into NAN values
data1.head(2)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0

# %%
bw50to80=data1[(data1['Salary']> 50000) &(data1['Salary'] < 80000)]
bw50to80.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 5 to 16
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  12 non-null     float64
#  1   Salary           12 non-null     float64
# dtypes: float64(2)
# memory usage: 288.0 bytes

# %%
exp5earn60=data1[(data1['Salary']> 60000) &(data1['YearsExperience'] > 5)]
exp5earn60.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries, 16 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  14 non-null     float64
#  1   Salary           14 non-null     float64
# dtypes: float64(2)
# memory usage: 336.0 bytes

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import *

# %%
lr=LinearRegression()   #making an object of linear regression class

# %%
x = data1[['YearsExperience']]
y = data1[['Salary']]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4,
random_state=0)

# %%
x
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
y
# Out:
#       Salary
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# 5    56642.0
# 6    60150.0
# 7    54445.0
# 8    64445.0
# 9    57189.0
# 10   63218.0
# 11   55794.0
# 12   56957.0
# 13   57081.0
# 14   61111.0
# 15   67938.0
# 16   66029.0
# 17   83088.0
# 18   81363.0
# 19   93940.0
# 20   91738.0
# 21   98273.0
# 22  101302.0
# 23  113812.0
# 24  109431.0
# 25  105582.0
# 26  116969.0
# 27  112635.0
# 28  122391.0
# 29  121872.0

# %%
y_test
# Out:
#       Salary
# 2    37731.0
# 28  122391.0
# 13   57081.0
# 10   63218.0
# 26  116969.0
# 24  109431.0
# 27  112635.0
# 11   55794.0
# 17   83088.0
# 22  101302.0
# 5    56642.0
# 16   66029.0

# %%
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9679117063698979

# %%
#As per the question independent variable is “education.num”.
x=data[['education_num']]
#dependent variable is “hours.per.week”
y=data['hours_per_week']

# %%
x
# Out:
#        education_num
# 0                 13
# 1                 13
# 2                  9
# 3                  7
# 4                 13
# ...              ...
# 32556             12
# 32557              9
# 32558              9
# 32559              9
# 32560              9
#
# [30162 rows x 1 columns]

# %%
y
# Out:
# 0        40
# 1        13
# 2        40
# 3        40
# 4        40
#          ..
# 32556    38
# 32557    40
# 32558    40
# 32559    20
# 32560    40
# Name: hours_per_week, Length: 30162, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=1)
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
y_pred   #These are the predicted values
# Out:
# array([40.1516711 , 38.07360531, 42.92242549, ..., 40.1516711 ,
#        38.7662939 , 40.1516711 ])

# %%
y_test #these are actual values
# Out:
# 12488    65
# 5130     50
# 8616     15
# 15453    40
# 13555    50
#          ..
# 23848    32
# 14755    20
# 11213    20
# 15473    40
# 37       25
# Name: hours_per_week, Length: 9049, dtype: int64

# %%
print('mean_squared_error :',mean_squared_error(y_test,y_pred))
# Out:
# mean_squared_error : 134.69130460518096

# %%
print('root_mean_squared_error :',mean_squared_error(y_test,y_pred, squared = False ))
# Out:
# root_mean_squared_error : 11.605658301241725

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 7.3622832713598605

# %%
r2_score(y_test,y_pred)
# Out:
# 0.02781973266918525

# %%
import seaborn as sns
sns.regplot(x=y_test,y=y_pred,color='red')
# Out:
# <Axes: xlabel='hours_per_week'>

# %%
3# The columns for which we are finding linear regression , they are not in linear relationship hence very bad accuracy we got
# Out:
# 3

# %% [markdown]
# # Logistic Regression

# %%
#AS per question occupation is indpendent and annual_income is target

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
lo=LogisticRegression()

# %%
x=data['occupation']
# giving particular labels to the elements in my columns
L=LabelEncoder()
x=L.fit_transform(x)
x
# Out:
# array([0, 3, 5, ..., 0, 0, 3])

# %%
x=pd.DataFrame(x)
x
# Out:
#         0
# 0       0
# 1       3
# 2       5
# 3       5
# 4       9
# ...    ..
# 30157  12
# 30158   6
# 30159   0
# 30160   0
# 30161   3
#
# [30162 rows x 1 columns]

# %%
y=data['annual_income'].replace('<=50K',0).replace('>50K',1)
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name: annual_income, Length: 30162, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=0)
lo=LogisticRegression()
lo.fit(x_train,y_train)
y_pred=lo.predict(x_test)

print('confusion_matrix :')
print(confusion_matrix(y_pred,y_test))
print('accuracy_score :',accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix :
# [[6764 2285]
#  [   0    0]]
# accuracy_score : 0.7474859100453088

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86      6764
#            1       0.00      0.00      0.00      2285
#
#     accuracy                           0.75      9049
#    macro avg       0.37      0.50      0.43      9049
# weighted avg       0.56      0.75      0.64      9049
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
data.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country annual_income
# 0          2174             0              40  United-States         <=50K
# ...

# %%
d=da    #We are taking this because income is most related to these columns
d.head()
# Out:
#    age         workclass  education
# 0   39         State-gov  Bachelors
# 1   50  Self-emp-not-inc  Bachelors
# 2   38           Private    HS-grad
# 3   53           Private       11th
# 4   28           Private  Bachelors

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'annual_income'],
#       dtype='object')

# %%
x=data.drop(columns = "annual_income")
x.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country
# 0          2174             0              40  United-States
# ...

# %%
y=data['annual_income'].replace('<=50K',0).replace('>50K',1)
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name: annual_income, Length: 30162, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in x.columns:
    if x[i].dtype=='object':
        x[i]=le.fit_transform(x[i])

# %%
x
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 0       39          5   77516          9             13               4
# 1       50          4   83311          9             13               2
# 2       38          2  215646         11              9               0
# 3       53          2  234721          1              7               2
# 4       28          2  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          2  257302          7             12               2
# 32557   40          2  154374         11              9               2
# 32558   58          2  151910         11              9               6
# 32559   22          2  201490         11              9               4
# 32560   52          3  287927         11              9               2
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=0)
lo=LogisticRegression()
lo.fit(x_train,y_train)
y_pred=lo.predict(x_test)

print('confusion_matrix :')
print(confusion_matrix(y_pred,y_test))
print('accuracy_score :',accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix :
# [[6627 1739]
#  [ 137  546]]
# accuracy_score : 0.7926842745054702
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print(classification_report(y_test,y_pred))
#recall==specificity =tn/tn+fp   senitivity=tp/tp+fn  precission =tp/tp+fp  support= combine 4sum 6627+1739+546=9049
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.98      0.88      6764
#            1       0.80      0.24      0.37      2285
#
#     accuracy                           0.79      9049
#    macro avg       0.80      0.61      0.62      9049
# weighted avg       0.79      0.79      0.75      9049

# %%
from sklearn.metrics import f1_score, recall_score, accuracy_score

f1_score = round(f1_score(y_test, y_pred), 2)
recall_score = round(recall_score(y_test, y_pred), 2)
#accuracy_score = accuracy_score(y_true, y_pred)

# %% [markdown]
# TP FP
#
# FN TN
#
# PRECISION  = TP/TP+FP
#
# RECALL     = TP/ TP+ FN
#
# ```
# # This is formatted as code
# ```

# %%
print("F1 Score for Logistic Regression Model 1 : {f1_score}".format(f1_score = f1_score))
# Out:
# F1 Score for Logistic Regression Model 1 : 0.05

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.97      0.84      6764
#            1       0.23      0.03      0.05      2285
#
#     accuracy                           0.73      9049
#    macro avg       0.49      0.50      0.45      9049
# weighted avg       0.62      0.73      0.64      9049

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
data=data.apply(L.fit_transform)
data.head()
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   22          5    2491          9             12               4
# 1   33          4    2727          9             12               2
# 2   21          2   13188         11              8               0
# 3   36          2   14354          1              6               2
# 4   11          2   18120          9             12               2
#
#    occupation  relationship  race  sex  capital_gain  capital_loss  \
# 0           0             1     4    1            24             0
# 1           3             0     4    1             0             0
# 2           5             1     4    1             0             0
# 3           5             0     2    1             0             0
# 4           9             5     2    0             0             0
#
#    hours_per_week  native_country  annual_income
# 0              39              38              0
# 1              12              38              0
# ...

# %%
#independent
x=data.iloc[:,:-1]
#dependent
y=data.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=1)
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)

print('confusion_matrix :')
print(confusion_matrix(y_pred,y_test))
print('accuracy_score :',accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix :
# [[5857  899]
#  [ 912 1381]]
# accuracy_score : 0.7998673886617306

# %%
from sklearn import tree
tree.plot_tree(dt, fontsize = 7)
# Out:
# [Text(0.6929199501441913, 0.9878048780487805, 'x[7] <= 0.5\ngini = 0.373\nsamples = 21113\nvalue = [15885, 5228]'),
#  Text(0.45008329097651506, 0.9634146341463414, 'x[4] <= 11.5\ngini = 0.495\nsamples = 8756\nvalue = [4806, 3950]'),
#  Text(0.2878357890118409, 0.9390243902439024, 'x[10] <= 77.0\ngini = 0.446\nsamples = 6140\nvalue = [4075, 2065]'),
#  Text(0.12766349027980284, 0.9146341463414634, 'x[4] <= 7.5\ngini = 0.42\nsamples = 5815\nvalue = [4068, 1747]'),
#  Text(0.034611235314672265, 0.8902439024390244, 'x[11] <= 40.0\ngini = 0.187\nsamples = 938\nvalue = [840, 98]'),
#  Text(0.024929859855411223, 0.8658536585365854, 'x[3] <= 2.5\ngini = 0.177\nsamples = 920\nvalue = [830, 90]'),
#  Text(0.011961990317776413, 0.8414634146341463, 'x[0] <= 19.5\ngini = 0.241\nsamples = 457\nvalue = [393, 64]'),
#  Text(0.004125292179925162, 0.8170731707317073, 'x[2] <= 319.0\ngini = 0.118\nsamples = 159\nvalue = [149, 10]'),
# ...

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=1)
rf=RandomForestClassifier(n_estimators=300)
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)

print('confusion_matrix :')
print(confusion_matrix(y_pred,y_test))
print('accuracy_score :',accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix :
# [[4173  590]
#  [ 310  960]]
# accuracy_score : 0.8508204873197415
